# %% [markdown]
# #### Code History

# %% [markdown]
#  - CODE
#     &ensp; : IITP_TCN
#  - DATE
#     &ensp; 2023-08-30 Created
#     &ensp; 2023-10-12 Modified (작업 재개)
#  - DESC
#     &ensp; : df_raw_temp_2023-08-09.csv 데이터를 분석
#  - DATA
#     1) Period : 2017-11-01 01:00:00 ~ 2021-06-30 09:00:00
#     2) Interval : 1H
#  - Link
#     &ensp; : https://github.com/ecokeco/tstl/tree/master/scripts

# %% [markdown]
# # 01. Code

# %% [markdown]
# ## 01-01. Init

# %% [markdown]
# ### 01-01-01. Init_Module Import

# %%
#region Basic_Import
## Basic
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import random
from pandas import DataFrame, Series

## Datetime
import time
import datetime as dt
from datetime import datetime, date, timedelta

from glob import glob
import requests
import json

## 시각화
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]

from scipy import stats

## TSNE
from sklearn.datasets import load_digits
from sklearn.manifold import TSNE

## 정규화
from sklearn.preprocessing import MinMaxScaler, StandardScaler

## Modeling, Model Training
from sklearn.model_selection import train_test_split, KFold, GridSearchCV

## Model 평가
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, mean_squared_error, r2_score   # model.score   

## Excel/CSV
import openpyxl, xlrd

import urllib
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus

from selenium import webdriver
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

## Init.
pd.options.display.float_format = '{:.10f}'.format
#endregion Basic_Import

# %%
## Import_DL
str_tar = "tf"
## For Torch
if str_tar == "torch":
    import torch
    import torch.nn as nn
    from torch.nn.utils import weight_norm
    print("Torch Imported")
## For TF
elif str_tar == "tf":
    import tensorflow as tf
    import tensorflow_addons as tfa
    print("Tensorflow Imported")
else:
    print("Error : Cannot be used except for Keywords")
    print(" : torch / tf")
# Out:
# Tensorflow Imported

# %%
## LSTM
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
## Import_Local (현재 프로그램에서 미사용)
from DEV_Common_Data_Analysis import print_desc_statistic
from DEV_Common_Data_Datetime import create_col_ymdhm, create_col_datetime, create_df_dt, conv_midnight_24to00, create_col_weekdays #, validate_date, list_invalidDate, calc_df_dt
from DEV_Common_Data_Preprocessing import resample_by_last, find_outlier_Usages, del_outlier_Usages
from DEV_Common_Data_Visualization import visualization_df
from DEV_KASI_Holiday import KASI_holiDay, KASI_restDay, KASI_anniDay
from DEV_KMA_Weather_ASOS import KMA_ASOS_DATA
from DEV_KDHC_Usage import KDHC_HEAT_Usage

# %% [markdown]
# ### 01-01-02. Config (Directory, Params)

# %%
## Init_config
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = "1"
random.seed(SEED)

# %%
## Define Todate str
str_now_ymd = pd.datetime.now().date()
str_now_y = pd.datetime.now().year
str_now_m = pd.datetime.now().month
str_now_d = pd.datetime.now().day
str_now_hr = pd.datetime.now().hour
str_now_min = pd.datetime.now().minute

print(pd.datetime.now())
print(str(str_now_y) + " / " + str(str_now_m)  + " / " + str(str_now_d))
print(str(str_now_hr) + " : " + str(str_now_min))
# Out:
# 2023-12-07 02:32:15.556641
# 2023 / 12 / 7
# 2 : 32

# %% [markdown]
# ## 01-02. Data Load (df_raw)

# %% [markdown]
# ### 01-02-01. KDHC Heat Usage

# %%
# Define data root directory
str_dir_kdhcHeat = "./data_Energy_KDHC_National_Heat/"
print(os.listdir(str_dir_kdhcHeat))

## CSV read
df_kdhc_cj = pd.read_csv(str_dir_kdhcHeat + 'KDHC_HEAT_CHEONGJU_2010_2021_1st_Check.csv')
df_kdhc_cj = df_kdhc_cj.rename(columns = {"HEAT_SELL_DATE" : "METER_DATE"})
df_kdhc_cj["METER_DATE"] = pd.to_datetime(df_kdhc_cj["METER_DATE"])
print(df_kdhc_cj.info())
df_kdhc_cj
# Out:
# ['KDHC_COMB_HEAT-CJ_ASOS_KASI_2010-2023.csv', 'KDHC_COMB_HEATxWEATHER_2019-2022.csv', 'KDHC_COMB_HEATxWEATHER_2019-2022_complete_analysis.csv', 'KDHC_COMB_HEATxWEATHER_2019-2022_linearReg.csv', 'KDHC_COMB_HEATxWEATHER_2019-2022_mean_imp.csv', 'KDHC_COMB_KANGNAMHEATxWEATHER_2019-2022.csv', 'KDHC_HEAT', 'KDHC_HEAT.zip', 'KDHC_HEAT_CHEONGJU_2010_2021.csv', 'KDHC_HEAT_CHEONGJU_2010_2021_1st_Check.csv', 'KDHC_HEAT_SEJONG_2014_2018.csv', 'KDHC_HEAT_SEJONG_2014_2018_1st_Check.csv', 'KDHC_NATIONAL_HEAT_hr.csv', 'KDHC_NATIONAL_HEAT_RAW_hr.csv']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105192 entries, 0 to 105191
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   METER_DATE       105192 non-null  datetime64[ns]
#  1   DAY_OF_THE_WEEK  105192 non-null  object
#  2   HOUR             105192 non-null  int64
#  3   CHEONGJU         105192 non-null  float64
#  4   YEAR             105192 non-null  int64
#  5   MONTH            105192 non-null  int64
#  6   DAY              105192 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 5.6+ MB
# None
#                 METER_DATE DAY_OF_THE_WEEK  HOUR       CHEONGJU  YEAR  MONTH  \
# 0      2010-01-01 01:00:00               금     1 178.0000000000  2010      1
# 1      2010-01-01 02:00:00               금     2 170.0000000000  2010      1
# 2      2010-01-01 03:00:00               금     3 165.0000000000  2010      1
# 3      2010-01-01 04:00:00               금     4 161.0000000000  2010      1
# 4      2010-01-01 05:00:00               금     5 162.0000000000  2010      1
# ...                    ...             ...   ...            ...   ...    ...
# 105187 2021-12-31 20:00:00               금    20 217.0000000000  2021     12
# 105188 2021-12-31 21:00:00               금    21 221.0000000000  2021     12
# 105189 2021-12-31 22:00:00               금    22 217.0000000000  2021     12
# 105190 2021-12-31 23:00:00               금    23 214.0000000000  2021     12
# 105191 2022-01-01 00:00:00               금     0 207.0000000000  2022      1
#
#         DAY
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 105187   31
# 105188   31
# 105189   31
# 105190   31
# 105191    1
#
# [105192 rows x 7 columns]

# %%
# Define data root directory
str_dir_ASOS = "./data_KMA_ASOS/"
print(os.listdir(str_dir_ASOS))

## CSV read
df_asos = pd.read_csv(str_dir_ASOS + 'KMA_ASOS_131_2010-2023_Cleansed_HR.csv'
                      , index_col = 0)
df_asos["METER_DATE"] = pd.to_datetime(df_asos["METER_DATE"])
print(df_asos.info())
df_asos
# Out:
# ['ASOS_108_2010.csv', 'ASOS_108_2010_D.csv', 'ASOS_108_2011.csv', 'ASOS_108_2011_D.csv', 'ASOS_108_2012.csv', 'ASOS_108_2012_D.csv', 'ASOS_108_2013.csv', 'ASOS_108_2013_D.csv', 'ASOS_108_2014.csv', 'ASOS_108_2014_D.csv', 'ASOS_108_2015.csv', 'ASOS_108_2015_D.csv', 'ASOS_108_2016.csv', 'ASOS_108_2016_D.csv', 'ASOS_108_2017.csv', 'ASOS_108_2017_D.csv', 'ASOS_108_2018.csv', 'ASOS_108_2018_D.csv', 'ASOS_108_2019.csv', 'ASOS_108_2019_D.csv', 'ASOS_108_2020.csv', 'ASOS_108_2020_D.csv', 'ASOS_108_2021.csv', 'ASOS_108_2021_D.csv', 'ASOS_108_2022.csv', 'ASOS_108_2022_D.csv', 'ASOS_108_2023.csv', 'ASOS_108_2023_D.csv', 'ASOS_119_2010.csv', 'ASOS_119_2010_D.csv', 'ASOS_119_2011.csv', 'ASOS_119_2011_D.csv', 'ASOS_119_2012.csv', 'ASOS_119_2012_D.csv', 'ASOS_119_2013.csv', 'ASOS_119_2013_D.csv', 'ASOS_119_2014.csv', 'ASOS_119_2014_D.csv', 'ASOS_119_2015.csv', 'ASOS_119_2015_D.csv', 'ASOS_119_2016.csv', 'ASOS_119_2016_D.csv', 'ASOS_119_2017.csv', 'ASOS_119_2017_D.csv', 'ASOS_119_2018.csv', 'ASOS_119_2018_D.csv', 'ASOS_119_2019.csv', 'ASOS_119_2019_D.csv', 'ASOS_119_2020.csv', 'ASOS_119_2020_D.csv', 'ASOS_119_2021.csv', 'ASOS_119_2021_D.csv', 'ASOS_119_2022.csv', 'ASOS_119_2022_D.csv', 'ASOS_119_2023.csv', 'ASOS_119_2023_D.csv', 'ASOS_131_2010.csv', 'ASOS_131_2010_D.csv', 'ASOS_131_2011.csv', 'ASOS_131_2011_D.csv', 'ASOS_131_2012.csv', 'ASOS_131_2012_D.csv', 'ASOS_131_2013.csv', 'ASOS_131_2013_D.csv', 'ASOS_131_2014.csv', 'ASOS_131_2014_D.csv', 'ASOS_131_2015.csv', 'ASOS_131_2015_D.csv', 'ASOS_131_2016.csv', 'ASOS_131_2016_D.csv', 'ASOS_131_2017.csv', 'ASOS_131_2017_D.csv', 'ASOS_131_2018.csv', 'ASOS_131_2018_D.csv', 'ASOS_131_2019.csv', 'ASOS_131_2019_D.csv', 'ASOS_131_2020.csv', 'ASOS_131_2020_D.csv', 'ASOS_131_2021.csv', 'ASOS_131_2021_D.csv', 'ASOS_131_2022.csv', 'ASOS_131_2022_D.csv', 'ASOS_131_2023.csv', 'ASOS_131_2023_D.csv', 'ASOS_143_2010.csv', 'ASOS_143_2010_D.csv', 'ASOS_143_2011.csv', 'ASOS_143_2011_D.csv', 'ASOS_143_2012.csv', 'ASOS_143_2012_D.csv', 'ASOS_143_2013.csv', 'ASOS_143_2013_D.csv', 'ASOS_143_2014.csv', 'ASOS_143_2014_D.csv', 'ASOS_143_2015.csv', 'ASOS_143_2015_D.csv', 'ASOS_143_2016.csv', 'ASOS_143_2016_D.csv', 'ASOS_143_2017.csv', 'ASOS_143_2017_D.csv', 'ASOS_143_2018.csv', 'ASOS_143_2018_D.csv', 'ASOS_143_2019.csv', 'ASOS_143_2019_D.csv', 'ASOS_143_2020.csv', 'ASOS_143_2020_D.csv', 'ASOS_143_2021.csv', 'ASOS_143_2021_D.csv', 'ASOS_143_2022.csv', 'ASOS_143_2022_D.csv', 'ASOS_143_2023.csv', 'ASOS_143_2023_D.csv', 'ASOS_156_2010.csv', 'ASOS_156_2010_D.csv', 'ASOS_156_2011.csv', 'ASOS_156_2011_D.csv', 'ASOS_156_2012.csv', 'ASOS_156_2012_D.csv', 'ASOS_156_2013.csv', 'ASOS_156_2013_D.csv', 'ASOS_156_2014.csv', 'ASOS_156_2014_D.csv', 'ASOS_156_2015.csv', 'ASOS_156_2015_D.csv', 'ASOS_156_2016.csv', 'ASOS_156_2016_D.csv', 'ASOS_156_2017.csv', 'ASOS_156_2017_D.csv', 'ASOS_156_2018.csv', 'ASOS_156_2018_D.csv', 'ASOS_156_2019.csv', 'ASOS_156_2019_D.csv', 'ASOS_156_2020.csv', 'ASOS_156_2020_D.csv', 'ASOS_156_2021.csv', 'ASOS_156_2021_D.csv', 'ASOS_156_2022.csv', 'ASOS_156_2022_D.csv', 'ASOS_156_2023.csv', 'ASOS_156_2023_D.csv', 'ASOS_159_2010.csv', 'ASOS_159_2010_D.csv', 'ASOS_159_2011.csv', 'ASOS_159_2011_D.csv', 'ASOS_159_2012.csv', 'ASOS_159_2012_D.csv', 'ASOS_159_2013.csv', 'ASOS_159_2013_D.csv', 'ASOS_159_2014.csv', 'ASOS_159_2014_D.csv', 'ASOS_159_2015.csv', 'ASOS_159_2015_D.csv', 'ASOS_159_2016.csv', 'ASOS_159_2016_D.csv', 'ASOS_159_2017.csv', 'ASOS_159_2017_D.csv', 'ASOS_159_2018.csv', 'ASOS_159_2018_D.csv', 'ASOS_159_2019.csv', 'ASOS_159_2019_D.csv', 'ASOS_159_2020.csv', 'ASOS_159_2020_D.csv', 'ASOS_159_2021.csv', 'ASOS_159_2021_D.csv', 'ASOS_159_2022.csv', 'ASOS_159_2022_D.csv', 'ASOS_159_2023.csv', 'ASOS_159_2023_D.csv', 'ASOS_253_2010.csv', 'ASOS_253_2010_D.csv', 'ASOS_253_2011.csv', 'ASOS_253_2011_D.csv', 'ASOS_253_2012.csv', 'ASOS_253_2012_D.csv', 'ASOS_253_2013.csv', 'ASOS_253_2013_D.csv', 'ASOS_253_2014.csv', 'ASOS_253_2014_D.csv', 'ASOS_253_2015.csv', 'ASOS_253_2015_D.csv', 'ASOS_253_2016.csv', 'ASOS_253_2016_D.c ...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119230 entries, 0 to 5279
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   METER_DATE       119230 non-null  datetime64[ns]
#  1   temp_outdoor     119230 non-null  float64
#  2   temp_dew_point   119230 non-null  float64
#  3   temp_ground      119230 non-null  float64
#  4   humidity         119230 non-null  float64
#  5   rainfall         119230 non-null  float64
#  6   snowfall         119230 non-null  float64
#  7   snowfall_3hr     119230 non-null  float64
#  8   wind_speed       119230 non-null  float64
#  9   wind_direction   119230 non-null  float64
#  10  pressure_vapor   119230 non-null  float64
#  11  pressure_area    119230 non-null  float64
#  12  pressure_sea     119230 non-null  float64
#  13  sunshine         119230 non-null  float64
#  14  solar_radiation  119230 non-null  float64
#  15  cloud_total      119230 non-null  float64
#  16  cloud_midlow     119230 non-null  float64
#  17  visual_range     119230 non-null  float64
# dtypes: datetime64[ns](1), float64(17)
# memory usage: 17.3 MB
# None
#               METER_DATE  temp_outdoor  temp_dew_point   temp_ground  \
# 0    2010-01-01 00:00:00 -9.0000000000  -18.0000000000 -8.0000000000
# 1    2010-01-01 01:00:00 -9.0000000000  -17.3000000000 -7.0000000000
# 2    2010-01-01 02:00:00 -9.3000000000  -15.6000000000 -6.1000000000
# 3    2010-01-01 03:00:00 -9.2000000000  -15.5000000000 -6.0000000000
# 4    2010-01-01 04:00:00 -9.7000000000  -15.0000000000 -7.5000000000
# ...                  ...           ...             ...           ...
# 5275 2023-08-08 19:00:00 30.6000000000   25.1000000000 30.1000000000
# 5276 2023-08-08 20:00:00 30.8000000000   24.4000000000 29.5000000000
# 5277 2023-08-08 21:00:00 31.3000000000   22.8000000000 29.1000000000
# 5278 2023-08-08 22:00:00 31.0000000000   22.5000000000 28.6000000000
# 5279 2023-08-08 23:00:00 30.5000000000   22.6000000000 28.2000000000
#
#           humidity     rainfall     snowfall  snowfall_3hr   wind_speed  \
# 0    48.0000000000 0.0000000000 0.0000000000  0.0000000000 0.9000000000
# 1    51.0000000000 0.0000000000 0.0000000000  0.0000000000 1.1000000000
# 2    60.0000000000 0.0000000000 0.0000000000  0.0000000000 0.9000000000
# 3    60.0000000000 0.0000000000 0.0000000000  0.0000000000 0.2000000000
# 4    65.0000000000 0.0000000000 0.0000000000  0.0000000000 0.5000000000
# ...            ...          ...          ...           ...          ...
# 5275 73.0000000000 0.0000000000 0.0000000000  0.0000000000 1.3000000000
# 5276 69.0000000000 0.0000000000 0.0000000000  0.0000000000 1.1000000000
# 5277 61.0000000000 0.0000000000 0.0000000000  0.0000000000 1.6000000000
# 5278 61.0000000000 0.0000000000 0.0000000000  0.0000000000 2.1000000000
# 5279 63.0000000000 0.0000000000 0.0000000000  0.0000000000 1.4000000000
#
#       wind_direction  pressure_vapor   pressure_area    pressure_sea  \
# 0     320.0000000000    1.5000000000 1016.2000000000 1023.6000000000
# 1     250.0000000000    1.6000000000 1016.4000000000 1023.8000000000
# 2     340.0000000000    1.8000000000 1016.6000000000 1024.0000000000
# 3       0.0000000000    1.8000000000 1016.9000000000 1024.3000000000
# 4     340.0000000000    1.9000000000 1016.5000000000 1023.9000000000
# ...              ...             ...             ...             ...
# 5275   50.0000000000   31.9000000000  995.0000000000 1001.5000000000
# 5276   20.0000000000   30.6000000000  995.5000000000 1002.0000000000
# 5277   70.0000000000   27.7000000000  995.9000000000 1002.4000000000
# 5278   70.0000000000   27.2000000000  995.9000000000 1002.4000000000
# 5279   70.0000000000   27.4000000000  996.3000000000 1002.8000000000
#
#          sunshine  solar_radiation  cloud_total  cloud_midlow    visual_range
# 0    0.0000000000     0.0000000000 0.0000000000  0.0000000000 1800.0000000000
# 1    0.0000000000     0.0000000000 0.0000000000  0.0000000000    0.0000000000
# 2    0.0000000000     0.0000000000 0.0000000000  0.0000000000    0.0000000000
# 3    0.0000000000     0.0000000000 7.0000000000  7.0000000000 1800.0000000000
# 4    0.0000000000     0.0000000000 2.0000000000  2.0000000000 1800.0000000000
# ...           ...              ...          ...           ...             ...
# 5275 0.0000000000     0.2800000000 8.0000000000  8.0000000000 3628.0000000000
# 5276 0.0000000000     0.0100000000 8.0000000000  8.0000000000 5000.0000000000
# 5277 0.0000000000     0.0000000000 7.0000000000  7.0000000000 5000.0000000000
# 5278 0.0000000000     0.0000000000 7.0000000000  7.0000000000 5000.0000000000
# 5279 0.0000000000     0.0000000000 7.0000000000  1.0000000000 5000.0000000000
#
# [119230 rows x 18 columns]

# %%
# Define data root directory
str_dir_KASI = "./data_Date_KASI/"
# print(os.listdir(str_dir_KASI))

## CSV read
df_kasi = pd.read_csv(str_dir_KASI + 'KASI_04-01_holiDay_distAdded_hr.csv')
df_kasi = df_kasi.rename(columns = {"DATETIME" : "METER_DATE"})
df_kasi = df_kasi[['METER_DATE', 'YEAR', 'MONTH', 'DAY', 'code_day_of_the_week', 'dist_from_holiday'
                   , 'HOUR', 'rest_YN']]
print(df_kasi.info())
df_kasi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122690 entries, 0 to 122689
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   METER_DATE            122690 non-null  object
#  1   YEAR                  122690 non-null  int64
#  2   MONTH                 122690 non-null  int64
#  3   DAY                   122690 non-null  int64
#  4   code_day_of_the_week  122690 non-null  int64
#  5   dist_from_holiday     122690 non-null  object
#  6   HOUR                  122690 non-null  int64
#  7   rest_YN               122690 non-null  object
# dtypes: int64(5), object(3)
# memory usage: 7.5+ MB
# None
#                  METER_DATE  YEAR  MONTH  DAY  code_day_of_the_week  \
# 0       2010-01-01 00:00:00  2010      1    1                     4
# 1       2010-01-01 01:00:00  2010      1    1                     4
# 2       2010-01-01 02:00:00  2010      1    1                     4
# 3       2010-01-01 03:00:00  2010      1    1                     4
# 4       2010-01-01 04:00:00  2010      1    1                     4
# ...                     ...   ...    ...  ...                   ...
# 122685  2023-12-30 20:00:00  2023     12   30                     5
# 122686  2023-12-30 21:00:00  2023     12   30                     5
# 122687  2023-12-30 22:00:00  2023     12   30                     5
# 122688  2023-12-30 23:00:00  2023     12   30                     5
# 122689  2023-12-31 00:00:00  2023     12   31                     6
#
#        dist_from_holiday  HOUR rest_YN
# 0                      0     0       1
# 1                     23     1       0
# 2                     22     2       0
# 3                     21     3       0
# 4                     20     4       0
# ...                  ...   ...     ...
# 122685                 0    20       1
# 122686                 0    21       1
# 122687                 0    22       1
# 122688                 0    23       1
# 122689                 0     0       1
#
# [122690 rows x 8 columns]

# %%
df_kasi.columns
# Out:
# Index(['METER_DATE', 'YEAR', 'MONTH', 'DAY', 'code_day_of_the_week',
#        'dist_from_holiday', 'HOUR', 'rest_YN'],
#       dtype='object')

# %%
date_kdhc_cj = pd.to_datetime(df_kdhc_cj["METER_DATE"])
dt_kdhc_cj_start = date_kdhc_cj.min()
dt_kdhc_cj_end = date_kdhc_cj.max()
print(dt_kdhc_cj_start)
print(dt_kdhc_cj_end)

date_asos = pd.to_datetime(df_asos["METER_DATE"])
date_asos_start = date_asos.min()
date_asos_end = date_asos.max()
print(date_asos_start)
print(date_asos_end)

date_kasi = pd.to_datetime(df_kasi["METER_DATE"])
date_kasi_start = date_kasi.min()
date_kasi_end = date_kasi.max()
print(date_kasi_start)
print(date_kasi_end)
# Out:
# 2010-01-01 01:00:00
# 2022-01-01 00:00:00
# 2010-01-01 00:00:00
# 2023-08-08 23:00:00
# 2010-01-01 00:00:00
# 2023-12-31 00:00:00

# %%
dt_start = max(dt_kdhc_cj_start, date_asos_start, date_kasi_start)
print(dt_start)
dt_end = max(dt_kdhc_cj_end, date_asos_end, date_kasi_end)
print(dt_end)
# Out:
# 2010-01-01 01:00:00
# 2023-12-31 00:00:00

# %%
df_dt = pd.DataFrame()
df_dt = create_df_dt(df_dt, "METER_DATE", dt_start, dt_end, "1H")
df_dt
# Out:
#                 METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0      2010-01-01 01:00:00          Friday  2010      1    1     1       0
# 1      2010-01-01 02:00:00          Friday  2010      1    1     2       0
# 2      2010-01-01 03:00:00          Friday  2010      1    1     3       0
# 3      2010-01-01 04:00:00          Friday  2010      1    1     4       0
# 4      2010-01-01 05:00:00          Friday  2010      1    1     5       0
# ...                    ...             ...   ...    ...  ...   ...     ...
# 122683 2023-12-30 20:00:00        Saturday  2023     12   30    20       0
# 122684 2023-12-30 21:00:00        Saturday  2023     12   30    21       0
# 122685 2023-12-30 22:00:00        Saturday  2023     12   30    22       0
# 122686 2023-12-30 23:00:00        Saturday  2023     12   30    23       0
# 122687 2023-12-31 00:00:00          Sunday  2023     12   31     0       0
#
#         code_day_of_the_week
# 0                          4
# 1                          4
# 2                          4
# 3                          4
# 4                          4
# ...                      ...
# 122683                     5
# 122684                     5
# 122685                     5
# 122686                     5
# 122687                     6
#
# [122688 rows x 8 columns]

# %%
print(df_kdhc_cj.columns)
print(df_asos.columns)
print(df_kasi.columns)
print(df_dt.columns)
# Out:
# Index(['METER_DATE', 'DAY_OF_THE_WEEK', 'HOUR', 'CHEONGJU', 'YEAR', 'MONTH',
#        'DAY'],
#       dtype='object')
# Index(['METER_DATE', 'temp_outdoor', 'temp_dew_point', 'temp_ground',
#        'humidity', 'rainfall', 'snowfall', 'snowfall_3hr', 'wind_speed',
#        'wind_direction', 'pressure_vapor', 'pressure_area', 'pressure_sea',
#        'sunshine', 'solar_radiation', 'cloud_total', 'cloud_midlow',
#        'visual_range'],
#       dtype='object')
# Index(['METER_DATE', 'YEAR', 'MONTH', 'DAY', 'code_day_of_the_week',
#        'dist_from_holiday', 'HOUR', 'rest_YN'],
#       dtype='object')
# Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week'],
#       dtype='object')

# %%
df_kdhc_cj = df_kdhc_cj[['METER_DATE', 'YEAR', 'MONTH', 'DAY'
                         , 'HOUR', 'CHEONGJU']]

df_kdhc_cj["METER_DATE"] = pd.to_datetime(df_kdhc_cj["METER_DATE"])
df_asos["METER_DATE"] = pd.to_datetime(df_asos["METER_DATE"])
df_kasi["METER_DATE"] = pd.to_datetime(df_kasi["METER_DATE"])
df_dt["METER_DATE"] = pd.to_datetime(df_dt["METER_DATE"])

df_merge = pd.DataFrame()
df_merge = pd.merge(df_dt, df_kasi
                    , how = 'left', on = ['METER_DATE', 'YEAR', 'MONTH', 'DAY', 'code_day_of_the_week'
                                          , 'HOUR'])
df_merge = pd.merge(df_merge, df_asos
                    , how = 'left', on = ['METER_DATE'])
df_merge = pd.merge(df_merge, df_kdhc_cj
                    , how = 'left', on = ['METER_DATE', 'YEAR', 'MONTH', 'DAY'
                                          , 'HOUR'])
df_merge.columns
# Out:
# Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'dist_from_holiday', 'rest_YN',
#        'temp_outdoor', 'temp_dew_point', 'temp_ground', 'humidity', 'rainfall',
#        'snowfall', 'snowfall_3hr', 'wind_speed', 'wind_direction',
#        'pressure_vapor', 'pressure_area', 'pressure_sea', 'sunshine',
#        'solar_radiation', 'cloud_total', 'cloud_midlow', 'visual_range',
#        'CHEONGJU'],
#       dtype='object')

# %%
## Export
df_merge.to_csv(str_dir_kdhcHeat + "KDHC_COMB_HEAT-CJ_ASOS_KASI_2010-2023.csv")

# %%
df_merge = pd.read_csv(str_dir_kdhcHeat + "KDHC_COMB_HEAT-CJ_ASOS_KASI_2010-2023.csv"
                       , index_col = 0)
df_raw = df_merge
df_raw
# Out:
#                  METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0       2010-01-01 01:00:00          Friday  2010      1    1     1       0
# 1       2010-01-01 02:00:00          Friday  2010      1    1     2       0
# 2       2010-01-01 03:00:00          Friday  2010      1    1     3       0
# 3       2010-01-01 04:00:00          Friday  2010      1    1     4       0
# 4       2010-01-01 05:00:00          Friday  2010      1    1     5       0
# ...                     ...             ...   ...    ...  ...   ...     ...
# 127067  2023-12-30 20:00:00        Saturday  2023     12   30    20       0
# 127068  2023-12-30 21:00:00        Saturday  2023     12   30    21       0
# 127069  2023-12-30 22:00:00        Saturday  2023     12   30    22       0
# 127070  2023-12-30 23:00:00        Saturday  2023     12   30    23       0
# 127071  2023-12-31 00:00:00          Sunday  2023     12   31     0       0
#
#         code_day_of_the_week dist_from_holiday rest_YN  ...  wind_direction  \
# 0                          4                23       0  ...  250.0000000000
# 1                          4                22       0  ...  340.0000000000
# 2                          4                21       0  ...    0.0000000000
# 3                          4                20       0  ...  340.0000000000
# 4                          4                19       0  ...    0.0000000000
# ...                      ...               ...     ...  ...             ...
# 127067                     5                 0       1  ...             NaN
# 127068                     5                 0       1  ...             NaN
# 127069                     5                 0       1  ...             NaN
# 127070                     5                 0       1  ...             NaN
# 127071                     6                 0       1  ...             NaN
#
#         pressure_vapor   pressure_area    pressure_sea     sunshine  \
# 0         1.6000000000 1016.4000000000 1023.8000000000 0.0000000000
# 1         1.8000000000 1016.6000000000 1024.0000000000 0.0000000000
# 2         1.8000000000 1016.9000000000 1024.3000000000 0.0000000000
# 3         1.9000000000 1016.5000000000 1023.9000000000 0.0000000000
# 4         1.9000000000 1016.2000000000 1023.7000000000 0.0000000000
# ...                ...             ...             ...          ...
# 127067             NaN             NaN             NaN          NaN
# 127068             NaN             NaN             NaN          NaN
# 127069             NaN             NaN             NaN          NaN
# 127070             NaN             NaN             NaN          NaN
# 127071             NaN             NaN             NaN          NaN
#
#         solar_radiation  cloud_total  cloud_midlow    visual_range  \
# 0          0.0000000000 0.0000000000  0.0000000000    0.0000000000
# 1          0.0000000000 0.0000000000  0.0000000000    0.0000000000
# 2          0.0000000000 7.0000000000  7.0000000000 1800.0000000000
# 3          0.0000000000 2.0000000000  2.0000000000 1800.0000000000
# 4          0.0000000000 0.0000000000  0.0000000000 1800.0000000000
# ...                 ...          ...           ...             ...
# 127067              NaN          NaN           NaN             NaN
# 127068              NaN          NaN           NaN             NaN
# 127069              NaN          NaN           NaN             NaN
# 127070              NaN          NaN           NaN             NaN
# 127071              NaN          NaN           NaN             NaN
#
#              CHEONGJU
# 0      178.0000000000
# 1      170.0000000000
# 2      165.0000000000
# 3      161.0000000000
# 4      162.0000000000
# ...               ...
# 127067            NaN
# 127068            NaN
# 127069            NaN
# 127070            NaN
# 127071            NaN
#
# [127072 rows x 28 columns]

# %% [markdown]
# #### 1-2-2. Data 시각화 (1차)

# %%
## Date의 형식을 datetime으로 변경
date = pd.to_datetime(df_raw['METER_DATE'])
date
# Out:
# 0        2010-01-01 01:00:00
# 1        2010-01-01 02:00:00
# 2        2010-01-01 03:00:00
# 3        2010-01-01 04:00:00
# 4        2010-01-01 05:00:00
#                  ...
# 127067   2023-12-30 20:00:00
# 127068   2023-12-30 21:00:00
# 127069   2023-12-30 22:00:00
# 127070   2023-12-30 23:00:00
# 127071   2023-12-31 00:00:00
# Name: METER_DATE, Length: 127072, dtype: datetime64[ns]

# %%
## 시각화
fig, ax1 = plt.subplots(figsize=(30,5))
ax1.plot(date, df_raw['CHEONGJU'], color='blue')
plt.show()

# %% [markdown]
# #### 1-2-3. Data 이상치 처리

# %%
## 이상치 기준 생성

## Q3 : 100개의 데이터로 가정 시, 25번째로 높은 값에 해당
## Q1 : 100개의 데이터로 가정 시, 75번째로 높은 값에 해당
## IQR : Q3 - Q1의 차이를 의미
## 이상치 : Q3 + 1.5 * IQR보다 높거나 Q1 - 1.5 * IQR보다 낮은 값을 의미

q3_df_raw = df_raw['CHEONGJU'].quantile(0.90)
q1_df_raw = df_raw['CHEONGJU'].quantile(0.25)
iqr_df_raw = q3_df_raw - q1_df_raw
print(q3_df_raw)
print(q1_df_raw)
# Out:
# 149.0
# 23.0

# %%
for i in range(0, len(df_raw)):
    outlier_usage = df_raw['CHEONGJU'].iloc[i]
    if ((outlier_usage > (q3_df_raw + 1.5 * iqr_df_raw)) or (outlier_usage < q1_df_raw - 1.5 * iqr_df_raw)):
        print(outlier_usage)
        df_raw['CHEONGJU'].iloc[i] = (df_raw['CHEONGJU'].iloc[i - 1] + df_raw['CHEONGJU'].iloc[i + 1]) / 2
    if outlier_usage < 0:
        print(outlier_usage)
        df_raw['CHEONGJU'].iloc[i] = 0
# Out:
# -0.7
# -72.3
# -72.3
# -71.3
# -72.3
# -94.2
# 667.0

# %%
## 시각화
fig, ax1 = plt.subplots(figsize=(30,5))
ax1.plot(date, df_raw['CHEONGJU'], color='blue')
plt.show()

# %%
df_raw = df_raw.dropna()
df_raw['CHEONGJU'] = df_raw['CHEONGJU'].interpolate()

# %%
## Date의 형식을 datetime으로 변경
date = pd.to_datetime(df_raw['METER_DATE'])
date

## 시각화
fig, ax1 = plt.subplots(figsize=(30,5))
ax1.plot(date, df_raw['CHEONGJU'], color='blue')
plt.show()

# %% [markdown]
# #### 1-2-4. Data 변수형 정리

# %%
df_raw_temp = pd.DataFrame(df_raw)

df_raw_temp['METER_DATE'] = pd.to_datetime(df_raw_temp['METER_DATE'])

df_raw_temp[(df_raw_temp['rest_YN'] == 'N')]['rest_YN'] = 0
df_raw_temp[(df_raw_temp['rest_YN'] == 'Y')]['rest_YN'] = 1

for i in range(0, len(df_raw_temp)):
    if((str(df_raw_temp['rest_YN'].iloc[i]) == 'N') | (df_raw_temp['rest_YN'].iloc[i] == '0')):
        df_raw_temp['rest_YN'].iloc[i] = 0
    if((str(df_raw_temp['rest_YN'].iloc[i]) == 'Y') | (df_raw_temp['rest_YN'].iloc[i] == '1')):
        df_raw_temp['rest_YN'].iloc[i] = 1

    if((str(df_raw_temp['dist_from_holiday'].iloc[i]) == '제헌절')
        | (str(df_raw_temp['dist_from_holiday'].iloc[i]) == '한글날')):
        df_raw_temp['dist_from_holiday'].iloc[i] = 0

# %%
df_raw_temp['rest_YN'] = pd.to_numeric(df_raw_temp['rest_YN'])
df_raw_temp['rest_YN'] = df_raw_temp['rest_YN'].apply(pd.to_numeric)

df_raw_temp['rest_YN'] = df_raw_temp['rest_YN'].astype('int32')

# %%
df_raw_temp = df_raw_temp.dropna()

## Train 중 오류
## ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type Timestamp).
## Train 전 오류
## ValueError: DataFrame.dtypes for data must be int, float or bool.
## Did not expect the data types in the following fields: DHW_METER_DATE, day_of_the_week, name_of_holiday
## 형식에 맞지 않는 열이 앞의 Preprocessing 단계에서 제거되어야 함.
## 1차
df_raw_temp = df_raw_temp[['YEAR', 'MONTH', 'DAY', 'code_day_of_the_week', 'dist_from_holiday', 'rest_YN'
                           , 'HOUR'
                           , 'temp_outdoor', 'temp_dew_point', 'temp_ground'
                           , 'humidity'
                           , 'rainfall', 'snowfall', 'snowfall_3hr'
                           , 'wind_speed', 'wind_direction'
                           , 'pressure_vapor', 'pressure_area', 'pressure_sea'
                           , 'sunshine'
                           , 'solar_radiation'
                           , 'cloud_total', 'cloud_midlow', 'visual_range'
                           , 'CHEONGJU']]

## 2차 YD, Dist 제거
# df_raw_temp = df_raw_temp[['MONTH', 'code_day_of_the_week', 'rest_YN'
#                            , 'HOUR'
#                            , 'temp_outdoor', 'temp_dew_point', 'temp_ground'
#                            , 'humidity'
#                            , 'rainfall', 'snowfall', 'snowfall_3hr'
#                            , 'wind_speed', 'wind_direction'
#                            , 'pressure_vapor', 'pressure_area', 'pressure_sea'
#                            , 'sunshine'
#                            , 'solar_radiation'
#                            , 'cloud_total', 'cloud_midlow', 'visual_range'
#                            , 'CHEONGJU']]

## 3차 YD, Code_day_of_the_week 제거
# df_raw_temp = df_raw_temp[['MONTH', 'dist_from_holiday', 'rest_YN'
#                            , 'HOUR'
#                            , 'temp_outdoor', 'temp_dew_point', 'temp_ground'
#                            , 'humidity'
#                            , 'rainfall', 'snowfall', 'snowfall_3hr'
#                            , 'wind_speed', 'wind_direction'
#                            , 'pressure_vapor', 'pressure_area', 'pressure_sea'
#                            , 'sunshine'
#                            , 'solar_radiation'
#                            , 'cloud_total', 'cloud_midlow', 'visual_range'
#                            , 'CHEONGJU']]

df_raw_temp['dist_from_holiday'] = df_raw_temp['dist_from_holiday'].astype("int64")

# %% [markdown]
# ## 01-03. Data Analysis

# %% [markdown]
# ### 01-03-01. Correlation

# %%
## 상관관계 분석
## 상관관계 변수 생성
df_corr = df_raw_temp.corr()
df_corr.corr()
# Out:
#                               YEAR         MONTH           DAY  \
# YEAR                  1.0000000000 -0.0608484344 -0.0523661399
# MONTH                -0.0608484344  1.0000000000 -0.0312560243
# DAY                  -0.0523661399 -0.0312560243  1.0000000000
# code_day_of_the_week -0.0285145040 -0.0279894741 -0.0243502015
# dist_from_holiday     0.0171597451  0.0271728717  0.0280099949
# rest_YN              -0.0415647983 -0.0365502821 -0.0321171611
# HOUR                 -0.0198044537 -0.1234207931 -0.0508657524
# temp_outdoor          0.0302833874  0.4763493314 -0.0340241971
# temp_dew_point       -0.0213512450  0.5531490277 -0.0307144051
# temp_ground           0.0403484958  0.4260261649 -0.0481924868
# humidity             -0.1549365719  0.4145393324 -0.0040718072
# rainfall             -0.1133904201  0.1030489956 -0.0575784603
# snowfall             -0.1951122922 -0.3305909121 -0.1334647848
# snowfall_3hr         -0.1193270673 -0.1202505372 -0.0664688524
# wind_speed            0.0444697721 -0.1171288436 -0.0844700263
# wind_direction       -0.1680784855 -0.2795273279 -0.0460446494
# pressure_vapor       -0.0309013981  0.5386625372 -0.0383017834
# pressure_area         0.0008138242 -0.4069630878  0.0371059858
# pressure_sea          0.0020798985 -0.4099592218  0.0368904966
# sunshine              0.0820036516 -0.1697802640 -0.0510232400
# solar_radiation       0.0786448740 -0.0766873476 -0.0642130798
# cloud_total           0.0481622542  0.2470078069 -0.0636817471
# cloud_midlow          0.0336230719  0.2177075879 -0.0646442121
# visual_range          0.5179354934 -0.0498178046 -0.0669012633
# CHEONGJU             -0.0158292586 -0.5221270442  0.0209413072
#
#                       code_day_of_the_week  dist_from_holiday       rest_YN  \
# YEAR                         -0.0285145040       0.0171597451 -0.0415647983
# MONTH                        -0.0279894741       0.0271728717 -0.0365502821
# DAY                          -0.0243502015       0.0280099949 -0.0321171611
# code_day_of_the_week          1.0000000000      -0.9899085018  0.9695092505
# dist_from_holiday            -0.9899085018       1.0000000000 -0.9392316736
# rest_YN                       0.9695092505      -0.9392316736  1.0000000000
# HOUR                          0.0338154988      -0.1411092778  0.0019065464
# temp_outdoor                 -0.0197226538       0.0055137173 -0.0237667041
# temp_dew_point               -0.0237238248       0.0301804982 -0.0232166131
# temp_ground                  -0.0272224485       0.0078488635 -0.0350227513
# humidity                     -0.0209954374       0.0784601175 -0.0087335335
# rainfall                     -0.0452971337       0.0564056588 -0.0498996703
# snowfall                     -0.0324469274       0.0352672970 -0.0490626828
# snowfall_3hr                 -0.0516281180       0.0537222835 -0.0667681372
# wind_speed                   -0.0638670642       0.0078622213 -0.0886337231
# wind_direction               -0.0487496775       0.0085575181 -0.0695505038
# pressure_vapor               -0.0274827557       0.0335497604 -0.0283408763
# pressure_area                 0.0369481142      -0.0355385820  0.0359723154
# pressure_sea                  0.0362664175      -0.0344288536  0.0354242618
# sunshine                     -0.0168327582      -0.0335487485 -0.0357867067
# solar_radiation              -0.0241409543      -0.0242700958 -0.0440481828
# cloud_total                  -0.0530132572       0.0787077254 -0.0589958241
# cloud_midlow                 -0.0560946364       0.0826303658 -0.0645167317
# visual_range                 -0.0348276014      -0.0062518025 -0.0542513360
# CHEONGJU                      0.0172338139      -0.0130042500  0.0173048146
#
#                               HOUR  temp_outdoor  temp_dew_point  \
# YEAR                 -0.0198044537  0.0302833874   -0.0213512450
# MONTH                -0.1234207931  0.4763493314    0.5531490277
# DAY                  -0.0508657524 -0.0340241971   -0.0307144051
# code_day_of_the_week  0.0338154988 -0.0197226538   -0.0237238248
# dist_from_holiday    -0.1411092778  0.0055137173    0.0301804982
# rest_YN               0.0019065464 -0.0237667041   -0.0232166131
# HOUR                  1.0000000000  0.1447611327   -0.0523949614
# temp_outdoor          0.1447611327  1.0000000000    0.9473653236
# temp_dew_point       -0.0523949614  0.9473653236    1.0000000000
# temp_ground           0.1738802371  0.9890887972    0.9006898534
# humidity             -0.5429082963  0.2427816634    0.5403497594
# rainfall             -0.1473976862  0.2048975913    0.3077973070
# snowfall             -0.1278366137 -0.6064234066   -0.5423721307
# snowfall_3hr         -0.1096362946 -0.1892596164   -0.1446773155
# wind_speed            0.4886148464  0.4376571879    0.2137642653
# wind_direction        0.3387704244 -0.0987146892   -0.2439203083
# pressure_vapor       -0.0547454784  0.9433622184    0.9986492356
# pressure_area        -0.0639458848 -0.9572952592   -0.9615513440
# pressure_sea         -0.0670456985 -0.9601799160   -0.9624837264
# sunshine              0.4020757689  0.1916577989   -0.0992324755
# solar_radiation       0.3928815057  0.4378815143    0.1598079043
# cloud_total          -0.2608309634  0.4725622103    0.6241857060
# cloud_midlow         -0.2828562718  0.3549582758    0.5339637354
# visual_range          0.2987859488  0.2612750716    0.0285629457
# CHEONGJU             -0.0567705112 -0.9921600153   -0.9529911162
#
#                        temp_ground  ...  wind_direction  pressure_vapor  \
# YEAR                  0.0403484958  ...   -0.1680784855   -0.0309013981
# MONTH                 0.4260261649  ...   -0.2795273279    0.5386625372
# DAY                  -0.0481924868  ...   -0.0460446494   -0.0383017834
# code_day_of_the_week -0.0272224485  ...   -0.0487496775   -0.0274827557
# dist_from_holiday     0.0078488635  ...    0.0085575181    0.0335497604
# rest_YN              -0.0350227513  ...   -0.0695505038   -0.0283408763
# HOUR                  0.1738802371  ...    0.3387704244   -0.0547454784
# temp_outdoor          0.9890887972  ...   -0.0987146892    0.9433622184
# temp_dew_point        0.9006898534  ...   -0.2439203083    0.9986492356
# temp_ground           1.0000000000  ...   -0.0482382668    0.8959844166
# humidity              0.1319685806  ...   -0.4786441216    0.5462692518
# rainfall              0.1594150001  ...   -0.1928154089    0.3153671246
# snowfall             -0.5902867708  ...    0.0380244966   -0.5265125041
# snowfall_3hr         -0.1989667949  ...   -0.0292390841   -0.1451249015
# wind_speed            0.5116016050  ...    0.3754992158    0.2121255364
# wind_direction       -0.0482382668  ...    1.0000000000   -0.2384295854
# pressure_vapor        0.8959844166  ...   -0.2384295854    1.0000000000
# pressure_area        -0.9292852953  ...    0.1097867815   -0.9623708895
# pressure_sea         -0.9327273256  ...    0.1090101676   -0.9631453816
# sunshine              0.3229051225  ...    0.3781618424   -0.1088448654
# solar_radiation       0.5608320445  ...    0.3072627141    0.1503509148
# cloud_total           0.4142357483  ...   -0.3353810708    0.6251635694
# cloud_midlow          0.2892093707  ...   -0.3245934193    0.5363793126
# visual_range          0.3356585002  ...    0.1441005779    0.0282834314
# CHEONGJU             -0.9798162317  ...    0.1153932723   -0.9467070568
#
#                       pressure_area  pressure_sea      sunshine  \
# YEAR                   0.0008138242  0.0020798985  0.0820036516
# MONTH                 -0.4069630878 -0.4099592218 -0.1697802640
# DAY                    0.0371059858  0.0368904966 -0.0510232400
# code_day_of_the_week   0.0369481142  0.0362664175 -0.0168327582
# dist_from_holiday     -0.0355385820 -0.0344288536 -0.0335487485
# rest_YN                0.0359723154  0.0354242618 -0.0357867067
# HOUR                  -0.0639458848 -0.0670456985  0.4020757689
# temp_outdoor          -0.9572952592 -0.9601799160  0.1916577989
# temp_dew_point        -0.9615513440 -0.9624837264 -0.0992324755
# temp_ground           -0.9292852953 -0.9327273256  0.3229051225
# humidity              -0.4014526088 -0.3966113594 -0.7972188602
# rainfall              -0.3091818439 -0.3062471619 -0.2936009994
# snowfall               0.5073898166  0.5113850346 -0.1698060276
# snowfall_3hr           0.1144793113  0.1170519902 -0.1488130215
# wind_speed            -0.4059140874 -0.4076861410  0.6250479689
# wind_direction         0.1097867815  0.1090101676  0.3781618424
# pressure_vapor        -0.9623708895 -0.9631453816 -0.1088448654
# pressure_area          1.0000000000  0.9999454714 -0.0192821702
# pressure_sea           0.9999454714  1.0000000000 -0.0253976355
# sunshine              -0.0192821702 -0.0253976355  1.0000000000
# solar_radiation       -0.2831971872 -0.2890822069  0.9480065217
# cloud_total           -0.6167289312 -0.6123859734 -0.4455671653
# cloud_midlow          -0.5231787407 -0.5178568950 -0.5316872858
# visual_range          -0.1465554692 -0.1496514139  0.6028872920
# CHEONGJU               0.9470105569  0.9500118056 -0.1758524356
#
#                       solar_radiation   cloud_total  cloud_midlow  \
# YEAR                     0.0786448740  0.0481622542  0.0336230719
# MONTH                   -0.0766873476  0.2470078069  0.2177075879
# DAY                     -0.0642130798 -0.0636817471 -0.0646442121
# code_day_of_the_week    -0.0241409543 -0.0530132572 -0.0560946364
# dist_from_holiday       -0.0242700958  0.0787077254  0.0826303658
# rest_YN                 -0.0440481828 -0.0589958241 -0.0645167317
# HOUR                     0.3928815057 -0.2608309634 -0.2828562718
# temp_outdoor             0.4378815143  0.4725622103  0.3549582758
# temp_dew_point           0.1598079043  0.6241857060  0.5339637354
# temp_ground              0.5608320445  0.4142357483  0.2892093707
# humidity                -0.6575460401  0.6594077611  0.6946690569
# rainfall                -0.2093450365  0.3765315316  0.3745074412
# snowfall                -0.3085708049 -0.2419929451 -0.1544929903
# snowfall_3hr            -0.1814232254 -0.0244256308  0.0092351908
# wind_speed               0.7218940835  0.0614585710 -0.0101388365
# wind_direction           0.3072627141 -0.3353810708 -0.3245934193
# pressure_vapor           0.1503509148  0.6251635694  0.5363793126
# pressure_area           -0.2831971872 -0.6167289312 -0.5231787407
# pressure_sea            -0.2890822069 -0.6123859734 -0.5178568950
# sunshine                 0.9480065217 -0.4455671653 -0.5316872858
# solar_radiation          1.0000000000 -0.2006210617 -0.3112484602
# cloud_total             -0.2006210617  1.0000000000  0.9619991667
# cloud_midlow            -0.3112484602  0.9619991667  1.0000000000
# visual_range             0.6262058171 -0.1148410689 -0.2000724538
# CHEONGJU                -0.4178227569 -0.4873632177 -0.3689409055
#
#                       visual_range      CHEONGJU
# YEAR                  0.5179354934 -0.0158292586
# MONTH                -0.0498178046 -0.5221270442
# DAY                  -0.0669012633  0.0209413072
# code_day_of_the_week -0.0348276014  0.0172338139
# dist_from_holiday    -0.0062518025 -0.0130042500
# rest_YN              -0.0542513360  0.0173048146
# HOUR                  0.2987859488 -0.0567705112
# temp_outdoor          0.2612750716 -0.9921600153
# temp_dew_point        0.0285629457 -0.9529911162
# temp_ground           0.3356585002 -0.9798162317
# humidity             -0.6090495793 -0.2814020974
# rainfall             -0.2526384877 -0.2235118643
# snowfall             -0.2671397322  0.6117113120
# snowfall_3hr         -0.1827444294  0.1848992450
# wind_speed            0.5876233063 -0.4060237109
# wind_direction        0.1441005779  0.1153932723
# pressure_vapor        0.0282834314 -0.9467070568
# pressure_area        -0.1465554692  0.9470105569
# pressure_sea         -0.1496514139  0.9500118056
# sunshine              0.6028872920 -0.1758524356
# solar_radiation       0.6262058171 -0.4178227569
# cloud_total          -0.1148410689 -0.4873632177
# cloud_midlow         -0.2000724538 -0.3689409055
# visual_range          1.0000000000 -0.2403655354
# CHEONGJU             -0.2403655354  1.0000000000
#
# [25 rows x 25 columns]

# %%
## Heatmap 분석
plt.figure(figsize=(30,20))
ax = sns.heatmap(df_corr, annot=True, fmt='.3f', cmap='Greens')
plt.title("Heatmap", fontsize=30)
plt.show()

# %% [markdown]
# #### 1-3-1. Data Split (Train/Test Setting)

# %%
print(df_raw_temp.columns)
print(df_raw_temp.info())
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'code_day_of_the_week', 'dist_from_holiday',
#        'rest_YN', 'HOUR', 'temp_outdoor', 'temp_dew_point', 'temp_ground',
#        'humidity', 'rainfall', 'snowfall', 'snowfall_3hr', 'wind_speed',
#        'wind_direction', 'pressure_vapor', 'pressure_area', 'pressure_sea',
#        'sunshine', 'solar_radiation', 'cloud_total', 'cloud_midlow',
#        'visual_range', 'CHEONGJU'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105191 entries, 0 to 109575
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   YEAR                  105191 non-null  int64
#  1   MONTH                 105191 non-null  int64
#  2   DAY                   105191 non-null  int64
#  3   code_day_of_the_week  105191 non-null  int64
#  4   dist_from_holiday     105191 non-null  int64
#  5   rest_YN               105191 non-null  int32
#  6   HOUR                  105191 non-null  int64
#  7   temp_outdoor          105191 non-null  float64
#  8   temp_dew_point        105191 non-null  float64
#  9   temp_ground           105191 non-null  float64
#  10  humidity              105191 non-null  float64
#  11  rainfall              105191 non-null  float64
#  12  snowfall              105191 non-null  float64
#  13  snowfall_3hr          105191 non-null  float64
#  14  wind_speed            105191 non-null  float64
#  15  wind_direction        105191 non-null  float64
#  16  pressure_vapor        105191 non-null  float64
#  17  pressure_area         105191 non-null  float64
#  18  pressure_sea          105191 non-null  float64
#  19  sunshine              105191 non-null  float64
#  20  solar_radiation       105191 non-null  float64
#  21  cloud_total           105191 non-null  float64
#  22  cloud_midlow          105191 non-null  float64
#  23  visual_range          105191 non-null  float64
#  24  CHEONGJU              105191 non-null  float64
# dtypes: float64(18), int32(1), int64(6)
# memory usage: 20.5 MB
# None

# %% [markdown]
# ### 1-5-1. DATA 분할

# %%
trainSet_Origin, testSet_Origin = train_test_split(df_raw_temp, test_size=0.3, shuffle=False)
print(trainSet_Origin.shape, testSet_Origin.shape)
# Out:
# (73633, 25) (31558, 25)

# %%
#### Data Split (Holiday YN)

## TrainSet으로부터 휴일 데이터만을 분리
print(trainSet_Origin.shape)
trainSet = trainSet_Origin

# ## 휴일일 때만
# trainSet = trainSet_Origin[(trainSet_Origin['rest_YN'] == 1)]
# trainSet = trainSet.drop(['rest_YN'], axis = 1)
print(trainSet.shape)

# ## Testset으로부터 휴일 데이터만을 분리
# ## ref. https://www.freecodecamp.org/korean/news/untitled/
print(testSet_Origin.shape)
testSet = testSet_Origin

# ## 특정일일 때만
# testSet = testSet_Origin[(testSet_Origin['rest_YN'] == 1)]
# testSet = testSet.drop(['rest_YN'], axis = 1)
print(testSet.shape)
# Out:
# (73633, 25)
# (73633, 25)
# (31558, 25)
# (31558, 25)

# %%
#### Feature/Target

trainXX = trainSet.drop(['CHEONGJU'],axis=1)
trainYY = trainSet[['CHEONGJU']]

#valX = val.drop(['INST_F'],axis=1)
#valY = val[['INST_F']]

testXX = testSet.drop(['CHEONGJU'],axis=1)
testYY = testSet[['CHEONGJU']]

# %%
trainXXindex = trainXX.index
trainXXcolumns = trainXX.columns

trainYYindex = trainYY.index
trainYYcolumns = trainYY.columns

testXXindex = testXX.index
testXXcolumns = testXX.columns

testYYindex = testYY.index
testYYcolumns = testYY.columns

#valXindex = valX.index
#valYindex = valY.index

#valXcolumns = valX.columns
#valYcolumns = valY.columns

# %%
d_trainXX=pd.DataFrame(trainXX, index=trainXXindex, columns=trainXXcolumns)
# d_trainXX=pd.DataFrame(trainXX, index=trainXXindex, columns=trainXXcolumns)
d_trainYY=trainYY

#d_valX=pd.DataFrame(func_valSet, index=valXindex, columns=valXcolumns)
#d_valY=valY

d_testXX=pd.DataFrame(testXX, index=testXXindex, columns=testXXcolumns)
# d_testXX=pd.DataFrame(trainXX, index=testXXindex, columns=testXXcolumns)
d_testYY=testYY

# %% [markdown]
# ### 2. Model

# %% [markdown]
#  - Link
#     : https://skyeong.net/309

# %% [markdown]
# #### 2-1. Build Model_LSTM

# %%
## Init Param_LSTM
# TIME_STEP = 1
# NUM_FEATRUE = 25

seqLength = 3

def buildDataSet(traindata, testdata, seqLength):
    xdata = []
    ydata = []

    for i in range(len(traindata)-seqLength+1):
        tx = traindata.iloc[i:i+seqLength]
        ty = testdata.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)

    return np.array(xdata), np.array(ydata)

trainX, trainY = buildDataSet(trainXX, trainYY, seqLength)
testX, testY = buildDataSet(testXX, testYY, seqLength)

# %%
## Train/Test Check
print(trainX.shape, trainY.shape)
print(testX.shape, testY.shape)
# Out:
# (73631, 3, 24) (73631, 1)
# (31556, 3, 24) (31556, 1)

# %%
model_input = tf.keras.layers.Input(shape=(seqLength, 24))

conv1 = tf.keras.layers.Conv1D(256, 1, activation='swish')(model_input)
pool1 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1)(conv1)
conv2 = tf.keras.layers.Conv1D(512, 1, activation='swish')(pool1)
pool2 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1)(conv2)
conv3 = tf.keras.layers.Conv1D(1024, 1, activation='swish')(pool2)
pool3 = tf.keras.layers.MaxPool1D(pool_size=1, strides=1)(conv3)
lstm0 = tf.keras.layers.LSTM(1024, activation='swish', dropout=0.15, return_sequences=True)(pool3)
lstm1 = tf.keras.layers.LSTM(512, activation='swish', dropout=0.15, return_sequences=True)(lstm0)
lstm2 = tf.keras.layers.LSTM(256, activation='swish', dropout=0.15, return_sequences=True)(lstm1)
lstm3 = tf.keras.layers.LSTM(128, activation='swish', dropout=0.15, return_sequences=False)(lstm2)
dense1 = tf.keras.layers.Dense(128, activation='swish')(lstm3)
dense2 = tf.keras.layers.Dense(64, activation='swish')(dense1)
dense3 = tf.keras.layers.Dense(32, activation='swish')(dense2)
dense4 = tf.keras.layers.Dense(16, activation='swish')(dense3)
model_output = tf.keras.layers.Dense(1)(dense4)
model = tf.keras.models.Model(model_input, model_output)

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 3, 24)]           0
#
#  conv1d_3 (Conv1D)           (None, 3, 256)            6400
#
#  max_pooling1d_3 (MaxPooling  (None, 2, 256)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 2, 512)            131584
#
#  max_pooling1d_4 (MaxPooling  (None, 1, 512)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 1, 1024)           525312
#
#  max_pooling1d_5 (MaxPooling  (None, 1, 1024)          0
#  1D)
#
#  lstm_4 (LSTM)               (None, 1, 1024)           8392704
#
#  lstm_5 (LSTM)               (None, 1, 512)            3147776
#
#  lstm_6 (LSTM)               (None, 1, 256)            787456
#
#  lstm_7 (LSTM)               (None, 128)               197120
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 13,215,745
# Trainable params: 13,215,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystopping = EarlyStopping(monitor='loss', patience=15)

model.compile(loss='mse', optimizer=tf.keras.optimizers.Adamax(learning_rate=1e-5,clipnorm=1.0), metrics=['mae'])

hist = model.fit(trainX, trainY, epochs=1000, batch_size=1024, callbacks=[earlystopping])
# Out:
# Epoch 1/1000
# 72/72 [==============================] - 3s 19ms/step - loss: 7242.7954 - mae: 65.6369
# Epoch 2/1000
# 72/72 [==============================] - 1s 16ms/step - loss: 6692.5991 - mae: 61.2730
# Epoch 3/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 5385.1191 - mae: 51.6422
# Epoch 4/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 3779.5198 - mae: 45.3425
# Epoch 5/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 3150.3113 - mae: 46.0406
# Epoch 6/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 3108.0823 - mae: 46.3352
# Epoch 7/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 3076.2422 - mae: 46.1375
# Epoch 8/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 3042.2917 - mae: 45.9521
# Epoch 9/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 3030.8184 - mae: 45.9056
# Epoch 10/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 3009.8118 - mae: 45.7570
# Epoch 11/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2999.3574 - mae: 45.6491
# Epoch 12/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2974.5276 - mae: 45.5101
# Epoch 13/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2973.8684 - mae: 45.4654
# Epoch 14/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2963.4106 - mae: 45.4852
# Epoch 15/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2945.5330 - mae: 45.3129
# Epoch 16/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2945.5947 - mae: 45.3477
# Epoch 17/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2934.2429 - mae: 45.2220
# Epoch 18/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2935.2881 - mae: 45.2639
# Epoch 19/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2929.8345 - mae: 45.2229
# Epoch 20/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2917.0657 - mae: 45.1350
# Epoch 21/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2910.0210 - mae: 45.0723
# Epoch 22/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 2911.3811 - mae: 45.0984
# Epoch 23/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2899.5339 - mae: 45.0270
# Epoch 24/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2898.1526 - mae: 45.0494
# Epoch 25/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2892.8164 - mae: 44.9620
# Epoch 26/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2888.6006 - mae: 45.0141
# Epoch 27/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 2887.6907 - mae: 44.9443
# Epoch 28/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 2879.8950 - mae: 44.9408
# Epoch 29/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2873.9607 - mae: 44.8899
# Epoch 30/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2865.1887 - mae: 44.8489
# Epoch 31/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2871.9045 - mae: 44.8828
# Epoch 32/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2858.8855 - mae: 44.8118
# Epoch 33/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2854.2854 - mae: 44.8085
# Epoch 34/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2847.8428 - mae: 44.7615
# Epoch 35/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2842.0635 - mae: 44.7193
# Epoch 36/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2843.6448 - mae: 44.7092
# Epoch 37/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2833.1018 - mae: 44.5969
# Epoch 38/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2825.6321 - mae: 44.6100
# Epoch 39/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2824.8496 - mae: 44.5326
# Epoch 40/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2810.3945 - mae: 44.4712
# Epoch 41/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2812.2021 - mae: 44.4682
# Epoch 42/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2801.9004 - mae: 44.3883
# Epoch 43/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2802.9324 - mae: 44.3837
# Epoch 44/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2793.1934 - mae: 44.3262
# Epoch 45/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2778.9897 - mae: 44.1370
# Epoch 46/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2771.1125 - mae: 44.1425
# Epoch 47/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2764.6936 - mae: 44.1157
# Epoch 48/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2751.8369 - mae: 43.9785
# Epoch 49/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2741.6245 - mae: 43.8934
# Epoch 50/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2732.7847 - mae: 43.8136
# Epoch 51/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2726.5254 - mae: 43.7453
# Epoch 52/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2707.7654 - mae: 43.6015
# Epoch 53/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2690.5530 - mae: 43.4410
# Epoch 54/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2670.9233 - mae: 43.2718
# Epoch 55/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2657.1257 - mae: 43.1462
# Epoch 56/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2640.5559 - mae: 42.9999
# Epoch 57/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2614.2349 - mae: 42.7640
# Epoch 58/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2595.5686 - mae: 42.5616
# Epoch 59/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2560.4595 - mae: 42.2062
# Epoch 60/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 2531.8328 - mae: 41.9250
# Epoch 61/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2496.7803 - mae: 41.5958
# Epoch 62/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2456.3889 - mae: 41.2010
# Epoch 63/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2415.6257 - mae: 40.7737
# Epoch 64/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2364.6013 - mae: 40.2044
# Epoch 65/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2311.8154 - mae: 39.6418
# Epoch 66/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 2257.0339 - mae: 38.9849
# Epoch 67/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2194.0420 - mae: 38.4013
# Epoch 68/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2122.9062 - mae: 37.5054
# Epoch 69/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 2044.6699 - mae: 36.5966
# Epoch 70/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 1956.8119 - mae: 35.5554
# Epoch 71/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 1869.6691 - mae: 34.5653
# Epoch 72/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 1783.4065 - mae: 33.5056
# Epoch 73/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 1684.4603 - mae: 32.2806
# Epoch 74/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 1587.9764 - mae: 30.9290
# Epoch 75/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 1495.2720 - mae: 29.8538
# Epoch 76/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 1399.8029 - mae: 28.5144
# Epoch 77/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 1316.7157 - mae: 27.4170
# Epoch 78/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 1244.0504 - mae: 26.4817
# Epoch 79/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 1184.7772 - mae: 25.6834
# Epoch 80/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 1108.2327 - mae: 24.7343
# Epoch 81/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 1043.8226 - mae: 23.9254
# Epoch 82/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 975.2833 - mae: 22.9652
# Epoch 83/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 929.3409 - mae: 22.3693
# Epoch 84/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 869.7375 - mae: 21.5850
# Epoch 85/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 834.7297 - mae: 21.1172
# Epoch 86/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 789.9792 - mae: 20.4822
# Epoch 87/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 750.2278 - mae: 19.9499
# Epoch 88/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 722.9203 - mae: 19.5332
# Epoch 89/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 700.3496 - mae: 19.1828
# Epoch 90/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 664.9136 - mae: 18.7495
# Epoch 91/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 648.8623 - mae: 18.4682
# Epoch 92/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 621.6437 - mae: 18.0281
# Epoch 93/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 601.3809 - mae: 17.7100
# Epoch 94/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 586.7939 - mae: 17.4454
# Epoch 95/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 569.9536 - mae: 17.2041
# Epoch 96/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 546.8356 - mae: 16.8605
# Epoch 97/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 534.3004 - mae: 16.6583
# Epoch 98/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 518.5917 - mae: 16.4296
# Epoch 99/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 509.0457 - mae: 16.2601
# Epoch 100/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 491.9480 - mae: 15.9620
# Epoch 101/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 478.8018 - mae: 15.7403
# Epoch 102/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 477.5611 - mae: 15.6897
# Epoch 103/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 463.0572 - mae: 15.4934
# Epoch 104/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 457.0447 - mae: 15.3821
# Epoch 105/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 447.9972 - mae: 15.2454
# Epoch 106/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 437.3750 - mae: 15.0454
# Epoch 107/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 435.1606 - mae: 14.9703
# Epoch 108/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 426.5078 - mae: 14.8524
# Epoch 109/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 421.3624 - mae: 14.7676
# Epoch 110/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 415.5594 - mae: 14.6637
# Epoch 111/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 408.3315 - mae: 14.5313
# Epoch 112/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 405.7803 - mae: 14.4939
# Epoch 113/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 397.6513 - mae: 14.3687
# Epoch 114/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 396.1074 - mae: 14.3247
# Epoch 115/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 388.8564 - mae: 14.1761
# Epoch 116/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 386.3421 - mae: 14.1433
# Epoch 117/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 381.9381 - mae: 14.0696
# Epoch 118/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 375.3347 - mae: 13.9768
# Epoch 119/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 372.2178 - mae: 13.8927
# Epoch 120/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 368.7359 - mae: 13.8322
# Epoch 121/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 363.4460 - mae: 13.7374
# Epoch 122/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 362.3064 - mae: 13.7259
# Epoch 123/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 357.6100 - mae: 13.6482
# Epoch 124/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 354.4731 - mae: 13.5587
# Epoch 125/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 350.9033 - mae: 13.4896
# Epoch 126/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 347.1872 - mae: 13.4201
# Epoch 127/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 345.5433 - mae: 13.4150
# Epoch 128/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 338.9949 - mae: 13.3019
# Epoch 129/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 339.4003 - mae: 13.3031
# Epoch 130/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 337.5778 - mae: 13.2723
# Epoch 131/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 337.8002 - mae: 13.2795
# Epoch 132/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 333.0328 - mae: 13.2004
# Epoch 133/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 331.4110 - mae: 13.1596
# Epoch 134/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 327.2876 - mae: 13.0957
# Epoch 135/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 326.0206 - mae: 13.0736
# Epoch 136/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 323.3527 - mae: 13.0136
# Epoch 137/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 318.9841 - mae: 12.9266
# Epoch 138/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 317.3838 - mae: 12.8931
# Epoch 139/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 314.2014 - mae: 12.8397
# Epoch 140/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 312.2291 - mae: 12.7875
# Epoch 141/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 312.7690 - mae: 12.8266
# Epoch 142/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 310.8691 - mae: 12.7694
# Epoch 143/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 307.0294 - mae: 12.6951
# Epoch 144/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 306.8416 - mae: 12.6782
# Epoch 145/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 304.5628 - mae: 12.6446
# Epoch 146/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 301.8671 - mae: 12.5909
# Epoch 147/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 300.9214 - mae: 12.5637
# Epoch 148/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 299.4088 - mae: 12.5259
# Epoch 149/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 300.1890 - mae: 12.5585
# Epoch 150/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 294.5623 - mae: 12.4445
# Epoch 151/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 291.0093 - mae: 12.3451
# Epoch 152/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 295.5991 - mae: 12.4751
# Epoch 153/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 288.9129 - mae: 12.3327
# Epoch 154/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 286.8829 - mae: 12.2868
# Epoch 155/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 287.6108 - mae: 12.3032
# Epoch 156/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 285.4041 - mae: 12.2566
# Epoch 157/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 285.8707 - mae: 12.2690
# Epoch 158/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 286.9443 - mae: 12.2739
# Epoch 159/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 282.3617 - mae: 12.1926
# Epoch 160/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 282.2987 - mae: 12.2031
# Epoch 161/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 276.7216 - mae: 12.0839
# Epoch 162/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 277.4609 - mae: 12.0861
# Epoch 163/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 277.1375 - mae: 12.0782
# Epoch 164/1000
# 72/72 [==============================] - 1s 16ms/step - loss: 272.5465 - mae: 12.0088
# Epoch 165/1000
# 72/72 [==============================] - 1s 16ms/step - loss: 273.5677 - mae: 12.0112
# Epoch 166/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 272.8957 - mae: 11.9998
# Epoch 167/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 271.7436 - mae: 11.9614
# Epoch 168/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 270.6742 - mae: 11.9417
# Epoch 169/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 268.5587 - mae: 11.8954
# Epoch 170/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 267.0992 - mae: 11.8827
# Epoch 171/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 267.4910 - mae: 11.8771
# Epoch 172/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 268.3544 - mae: 11.9081
# Epoch 173/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 264.2799 - mae: 11.8149
# Epoch 174/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 263.2357 - mae: 11.7827
# Epoch 175/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 262.0465 - mae: 11.7597
# Epoch 176/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 261.5464 - mae: 11.7405
# Epoch 177/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 259.0915 - mae: 11.7035
# Epoch 178/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 257.7508 - mae: 11.6850
# Epoch 179/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 257.4738 - mae: 11.6812
# Epoch 180/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 256.2309 - mae: 11.6216
# Epoch 181/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 254.8516 - mae: 11.5929
# Epoch 182/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 254.0218 - mae: 11.5761
# Epoch 183/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 254.1152 - mae: 11.5836
# Epoch 184/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 251.4859 - mae: 11.5194
# Epoch 185/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 250.3419 - mae: 11.4916
# Epoch 186/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 250.6609 - mae: 11.5120
# Epoch 187/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 248.6271 - mae: 11.4518
# Epoch 188/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 246.1829 - mae: 11.4269
# Epoch 189/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 246.4194 - mae: 11.4161
# Epoch 190/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 244.1418 - mae: 11.3836
# Epoch 191/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 247.5916 - mae: 11.4301
# Epoch 192/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 245.4070 - mae: 11.3924
# Epoch 193/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 245.4430 - mae: 11.4030
# Epoch 194/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 243.7125 - mae: 11.3464
# Epoch 195/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 241.2459 - mae: 11.2951
# Epoch 196/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 242.5343 - mae: 11.3195
# Epoch 197/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 240.2470 - mae: 11.2976
# Epoch 198/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 241.4635 - mae: 11.3031
# Epoch 199/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 238.5864 - mae: 11.2459
# Epoch 200/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 238.3584 - mae: 11.2182
# Epoch 201/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 237.9625 - mae: 11.2252
# Epoch 202/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 235.9564 - mae: 11.1794
# Epoch 203/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 236.2743 - mae: 11.2018
# Epoch 204/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 233.6195 - mae: 11.1429
# Epoch 205/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 233.4446 - mae: 11.1372
# Epoch 206/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 233.3352 - mae: 11.1213
# Epoch 207/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 231.6591 - mae: 11.0821
# Epoch 208/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 234.6005 - mae: 11.1420
# Epoch 209/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 231.4344 - mae: 11.0816
# Epoch 210/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 230.6165 - mae: 11.0721
# Epoch 211/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 230.9887 - mae: 11.0497
# Epoch 212/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 231.0055 - mae: 11.0551
# Epoch 213/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 228.7847 - mae: 10.9982
# Epoch 214/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 227.8429 - mae: 11.0040
# Epoch 215/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 227.3336 - mae: 10.9825
# Epoch 216/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 227.4520 - mae: 11.0085
# Epoch 217/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 225.7736 - mae: 10.9373
# Epoch 218/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 224.9813 - mae: 10.9245
# Epoch 219/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 226.3466 - mae: 10.9550
# Epoch 220/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 224.2379 - mae: 10.9119
# Epoch 221/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 223.8775 - mae: 10.8811
# Epoch 222/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 224.2160 - mae: 10.9164
# Epoch 223/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 222.4672 - mae: 10.8676
# Epoch 224/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 223.3266 - mae: 10.8872
# Epoch 225/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 221.3123 - mae: 10.8289
# Epoch 226/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 220.2590 - mae: 10.8189
# Epoch 227/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 222.6843 - mae: 10.8774
# Epoch 228/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 221.0325 - mae: 10.8350
# Epoch 229/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 219.2140 - mae: 10.7926
# Epoch 230/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 220.5361 - mae: 10.8180
# Epoch 231/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 219.2424 - mae: 10.7992
# Epoch 232/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 219.1036 - mae: 10.7768
# Epoch 233/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 219.0675 - mae: 10.7762
# Epoch 234/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 216.9627 - mae: 10.7319
# Epoch 235/1000
# 72/72 [==============================] - 1s 16ms/step - loss: 217.5636 - mae: 10.7347
# Epoch 236/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 215.7549 - mae: 10.6981
# Epoch 237/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 216.2768 - mae: 10.7179
# Epoch 238/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 214.9689 - mae: 10.6610
# Epoch 239/1000
# 72/72 [==============================] - 1s 16ms/step - loss: 213.9429 - mae: 10.6621
# Epoch 240/1000
# 72/72 [==============================] - 1s 16ms/step - loss: 213.7314 - mae: 10.6579
# Epoch 241/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 212.7580 - mae: 10.6375
# Epoch 242/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 213.2936 - mae: 10.6587
# Epoch 243/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 214.3347 - mae: 10.6640
# Epoch 244/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 212.8523 - mae: 10.6487
# Epoch 245/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 213.4462 - mae: 10.6394
# Epoch 246/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 212.1533 - mae: 10.6162
# Epoch 247/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 212.9019 - mae: 10.6246
# Epoch 248/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 212.3958 - mae: 10.6171
# Epoch 249/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 210.3233 - mae: 10.5746
# Epoch 250/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 212.6883 - mae: 10.6050
# Epoch 251/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 209.7956 - mae: 10.5491
# Epoch 252/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 210.4548 - mae: 10.5799
# Epoch 253/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 210.6556 - mae: 10.5812
# Epoch 254/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 208.4484 - mae: 10.5303
# Epoch 255/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 209.4839 - mae: 10.5348
# Epoch 256/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 207.9305 - mae: 10.5341
# Epoch 257/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 208.6863 - mae: 10.5291
# Epoch 258/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 207.6348 - mae: 10.5079
# Epoch 259/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 206.3669 - mae: 10.4786
# Epoch 260/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 205.1576 - mae: 10.4619
# Epoch 261/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 204.1900 - mae: 10.4188
# Epoch 262/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 204.7889 - mae: 10.4403
# Epoch 263/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 206.0715 - mae: 10.4639
# Epoch 264/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 207.7988 - mae: 10.5099
# Epoch 265/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 206.4201 - mae: 10.4880
# Epoch 266/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 204.3856 - mae: 10.4268
# Epoch 267/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 205.2835 - mae: 10.4513
# Epoch 268/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 203.4698 - mae: 10.3947
# Epoch 269/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 204.6748 - mae: 10.4003
# Epoch 270/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 203.9388 - mae: 10.3993
# Epoch 271/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 202.5534 - mae: 10.3781
# Epoch 272/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 201.6030 - mae: 10.3466
# Epoch 273/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 200.6663 - mae: 10.3351
# Epoch 274/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 201.3360 - mae: 10.3515
# Epoch 275/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 200.6423 - mae: 10.3398
# Epoch 276/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 201.4571 - mae: 10.3395
# Epoch 277/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 201.4847 - mae: 10.3332
# Epoch 278/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 200.4112 - mae: 10.3255
# Epoch 279/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 200.0402 - mae: 10.3090
# Epoch 280/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 199.2842 - mae: 10.2867
# Epoch 281/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 198.6826 - mae: 10.2773
# Epoch 282/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 198.6182 - mae: 10.2858
# Epoch 283/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 199.3598 - mae: 10.2884
# Epoch 284/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 200.1527 - mae: 10.3203
# Epoch 285/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 198.1528 - mae: 10.2730
# Epoch 286/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 199.8571 - mae: 10.2915
# Epoch 287/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 200.1992 - mae: 10.3079
# Epoch 288/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 197.2606 - mae: 10.2385
# Epoch 289/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 198.4223 - mae: 10.2698
# Epoch 290/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 199.1417 - mae: 10.2807
# Epoch 291/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 196.7198 - mae: 10.2291
# Epoch 292/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 195.7584 - mae: 10.1903
# Epoch 293/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 198.3881 - mae: 10.2651
# Epoch 294/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 196.7396 - mae: 10.2399
# Epoch 295/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 197.0980 - mae: 10.2425
# Epoch 296/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 196.2999 - mae: 10.2070
# Epoch 297/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 194.3849 - mae: 10.1712
# Epoch 298/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 195.3282 - mae: 10.1942
# Epoch 299/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 195.8714 - mae: 10.2097
# Epoch 300/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 194.5743 - mae: 10.1725
# Epoch 301/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 193.6951 - mae: 10.1462
# Epoch 302/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 193.8549 - mae: 10.1656
# Epoch 303/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 193.5947 - mae: 10.1455
# Epoch 304/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 194.0103 - mae: 10.1582
# Epoch 305/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 194.4890 - mae: 10.1492
# Epoch 306/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 193.8452 - mae: 10.1509
# Epoch 307/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 193.1682 - mae: 10.1267
# Epoch 308/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 193.8979 - mae: 10.1522
# Epoch 309/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 193.1148 - mae: 10.1392
# Epoch 310/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 193.2417 - mae: 10.1580
# Epoch 311/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 192.6712 - mae: 10.1120
# Epoch 312/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 190.9033 - mae: 10.0710
# Epoch 313/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 191.8981 - mae: 10.0828
# Epoch 314/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 190.7785 - mae: 10.0767
# Epoch 315/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 192.0273 - mae: 10.1115
# Epoch 316/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 192.0098 - mae: 10.0782
# Epoch 317/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 191.6689 - mae: 10.0836
# Epoch 318/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 190.9122 - mae: 10.0770
# Epoch 319/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 191.2063 - mae: 10.0765
# Epoch 320/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 189.8942 - mae: 10.0301
# Epoch 321/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 190.1566 - mae: 10.0736
# Epoch 322/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 189.8806 - mae: 10.0478
# Epoch 323/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 189.4616 - mae: 10.0417
# Epoch 324/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 187.5889 - mae: 10.0005
# Epoch 325/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 188.4843 - mae: 9.9996
# Epoch 326/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 188.7749 - mae: 10.0291
# Epoch 327/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 189.0822 - mae: 10.0264
# Epoch 328/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 188.2826 - mae: 10.0076
# Epoch 329/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 190.6259 - mae: 10.0615
# Epoch 330/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 189.4827 - mae: 10.0160
# Epoch 331/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 189.7635 - mae: 10.0497
# Epoch 332/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 188.7468 - mae: 10.0196
# Epoch 333/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 188.5941 - mae: 10.0100
# Epoch 334/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 188.1639 - mae: 10.0039
# Epoch 335/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 188.6738 - mae: 10.0015
# Epoch 336/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 188.3661 - mae: 10.0005
# Epoch 337/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 186.6510 - mae: 9.9655
# Epoch 338/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 186.6506 - mae: 9.9598
# Epoch 339/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 185.6673 - mae: 9.9275
# Epoch 340/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 187.8127 - mae: 9.9902
# Epoch 341/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 187.0081 - mae: 9.9655
# Epoch 342/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 185.7753 - mae: 9.9523
# Epoch 343/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 186.7493 - mae: 9.9809
# Epoch 344/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 184.8260 - mae: 9.9267
# Epoch 345/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 187.5675 - mae: 9.9854
# Epoch 346/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 188.1030 - mae: 9.9791
# Epoch 347/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 184.5408 - mae: 9.9021
# Epoch 348/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 183.8746 - mae: 9.8854
# Epoch 349/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 185.6978 - mae: 9.9333
# Epoch 350/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 185.9193 - mae: 9.9307
# Epoch 351/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 184.8788 - mae: 9.9138
# Epoch 352/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 183.8235 - mae: 9.8859
# Epoch 353/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 184.0322 - mae: 9.8809
# Epoch 354/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 184.3216 - mae: 9.9028
# Epoch 355/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 185.1808 - mae: 9.9151
# Epoch 356/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 183.0985 - mae: 9.8658
# Epoch 357/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 183.7254 - mae: 9.8791
# Epoch 358/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 183.1058 - mae: 9.8643
# Epoch 359/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 184.8925 - mae: 9.9261
# Epoch 360/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 183.2073 - mae: 9.8753
# Epoch 361/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 185.2356 - mae: 9.9161
# Epoch 362/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 184.7092 - mae: 9.8901
# Epoch 363/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 183.4301 - mae: 9.8840
# Epoch 364/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 181.7328 - mae: 9.8360
# Epoch 365/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 182.8545 - mae: 9.8585
# Epoch 366/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 182.3253 - mae: 9.8402
# Epoch 367/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 181.5646 - mae: 9.8312
# Epoch 368/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 181.9058 - mae: 9.8289
# Epoch 369/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 183.5142 - mae: 9.8846
# Epoch 370/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 181.3574 - mae: 9.8183
# Epoch 371/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 182.5929 - mae: 9.8371
# Epoch 372/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 181.3015 - mae: 9.8115
# Epoch 373/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 181.9055 - mae: 9.8222
# Epoch 374/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 180.9408 - mae: 9.8057
# Epoch 375/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 180.7922 - mae: 9.7964
# Epoch 376/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 181.4389 - mae: 9.8154
# Epoch 377/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 181.2785 - mae: 9.8285
# Epoch 378/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 180.4361 - mae: 9.7877
# Epoch 379/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 179.9309 - mae: 9.7772
# Epoch 380/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 180.7778 - mae: 9.8110
# Epoch 381/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 180.1675 - mae: 9.8009
# Epoch 382/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 180.3957 - mae: 9.7923
# Epoch 383/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 179.1710 - mae: 9.7577
# Epoch 384/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 179.0500 - mae: 9.7694
# Epoch 385/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 179.7512 - mae: 9.7788
# Epoch 386/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 178.6259 - mae: 9.7510
# Epoch 387/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 179.0362 - mae: 9.7839
# Epoch 388/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 178.0118 - mae: 9.7299
# Epoch 389/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.0757 - mae: 9.7080
# Epoch 390/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.5612 - mae: 9.7170
# Epoch 391/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.6816 - mae: 9.7311
# Epoch 392/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 179.4738 - mae: 9.7654
# Epoch 393/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 178.7173 - mae: 9.7616
# Epoch 394/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.6084 - mae: 9.7284
# Epoch 395/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.6407 - mae: 9.7236
# Epoch 396/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.4662 - mae: 9.7084
# Epoch 397/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.7342 - mae: 9.7142
# Epoch 398/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.2638 - mae: 9.7111
# Epoch 399/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 178.4148 - mae: 9.7213
# Epoch 400/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 176.8298 - mae: 9.6856
# Epoch 401/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.5058 - mae: 9.7251
# Epoch 402/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.8986 - mae: 9.6802
# Epoch 403/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 178.2243 - mae: 9.7181
# Epoch 404/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 176.8760 - mae: 9.7115
# Epoch 405/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.1702 - mae: 9.6950
# Epoch 406/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.9373 - mae: 9.6792
# Epoch 407/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 176.4468 - mae: 9.6836
# Epoch 408/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 177.1219 - mae: 9.7064
# Epoch 409/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.6438 - mae: 9.6715
# Epoch 410/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 176.2187 - mae: 9.6809
# Epoch 411/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 177.3778 - mae: 9.7205
# Epoch 412/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 176.2419 - mae: 9.6662
# Epoch 413/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.2341 - mae: 9.6622
# Epoch 414/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 174.8143 - mae: 9.6517
# Epoch 415/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.0685 - mae: 9.6519
# Epoch 416/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.1545 - mae: 9.6676
# Epoch 417/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 174.7920 - mae: 9.6376
# Epoch 418/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 173.9482 - mae: 9.6148
# Epoch 419/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.7918 - mae: 9.6637
# Epoch 420/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.0773 - mae: 9.6473
# Epoch 421/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.1702 - mae: 9.6623
# Epoch 422/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 174.0906 - mae: 9.6316
# Epoch 423/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 173.1871 - mae: 9.6024
# Epoch 424/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 174.9590 - mae: 9.6430
# Epoch 425/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 174.0143 - mae: 9.6324
# Epoch 426/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.5619 - mae: 9.6558
# Epoch 427/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 174.0971 - mae: 9.6275
# Epoch 428/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 174.6332 - mae: 9.6418
# Epoch 429/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 175.3887 - mae: 9.6585
# Epoch 430/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 173.7416 - mae: 9.6173
# Epoch 431/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 173.5260 - mae: 9.6234
# Epoch 432/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 173.0277 - mae: 9.6016
# Epoch 433/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 173.3382 - mae: 9.6086
# Epoch 434/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 173.6528 - mae: 9.6247
# Epoch 435/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 172.7449 - mae: 9.5969
# Epoch 436/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 173.5572 - mae: 9.5984
# Epoch 437/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 172.5083 - mae: 9.5725
# Epoch 438/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 171.9750 - mae: 9.5676
# Epoch 439/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 172.7899 - mae: 9.5804
# Epoch 440/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 170.9683 - mae: 9.5330
# Epoch 441/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 171.7295 - mae: 9.5702
# Epoch 442/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 171.4041 - mae: 9.5596
# Epoch 443/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 171.4237 - mae: 9.5439
# Epoch 444/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 172.0205 - mae: 9.5539
# Epoch 445/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 172.0199 - mae: 9.5702
# Epoch 446/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 172.6703 - mae: 9.5792
# Epoch 447/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 170.6488 - mae: 9.5478
# Epoch 448/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 170.7625 - mae: 9.5318
# Epoch 449/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 171.3983 - mae: 9.5572
# Epoch 450/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 172.0314 - mae: 9.5623
# Epoch 451/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 170.4223 - mae: 9.5257
# Epoch 452/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 171.1865 - mae: 9.5406
# Epoch 453/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 172.3998 - mae: 9.5761
# Epoch 454/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 172.2617 - mae: 9.5773
# Epoch 455/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 171.3918 - mae: 9.5515
# Epoch 456/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.5578 - mae: 9.4988
# Epoch 457/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.9936 - mae: 9.5223
# Epoch 458/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 170.0419 - mae: 9.5182
# Epoch 459/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 170.3314 - mae: 9.5339
# Epoch 460/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.1649 - mae: 9.4963
# Epoch 461/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 170.3895 - mae: 9.5097
# Epoch 462/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.7035 - mae: 9.5150
# Epoch 463/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.7258 - mae: 9.4969
# Epoch 464/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.6613 - mae: 9.5008
# Epoch 465/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.4595 - mae: 9.5050
# Epoch 466/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.7781 - mae: 9.4933
# Epoch 467/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.6649 - mae: 9.5042
# Epoch 468/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 170.7336 - mae: 9.5230
# Epoch 469/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.1263 - mae: 9.4827
# Epoch 470/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.9621 - mae: 9.4826
# Epoch 471/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 168.3065 - mae: 9.4873
# Epoch 472/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.1506 - mae: 9.4710
# Epoch 473/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.2656 - mae: 9.4578
# Epoch 474/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.2327 - mae: 9.4781
# Epoch 475/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 169.5536 - mae: 9.4794
# Epoch 476/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.7283 - mae: 9.4835
# Epoch 477/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.5771 - mae: 9.4652
# Epoch 478/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.5931 - mae: 9.4629
# Epoch 479/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.7088 - mae: 9.4429
# Epoch 480/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.3269 - mae: 9.4689
# Epoch 481/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 168.1927 - mae: 9.4589
# Epoch 482/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.6110 - mae: 9.4534
# Epoch 483/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.7430 - mae: 9.4262
# Epoch 484/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.0970 - mae: 9.4374
# Epoch 485/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 168.1002 - mae: 9.4645
# Epoch 486/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.7182 - mae: 9.4567
# Epoch 487/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.8442 - mae: 9.4284
# Epoch 488/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.5241 - mae: 9.4326
# Epoch 489/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.5525 - mae: 9.4155
# Epoch 490/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.6568 - mae: 9.4459
# Epoch 491/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.6592 - mae: 9.4479
# Epoch 492/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.7213 - mae: 9.4547
# Epoch 493/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 166.8738 - mae: 9.4355
# Epoch 494/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.7148 - mae: 9.4221
# Epoch 495/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.3703 - mae: 9.4038
# Epoch 496/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.5987 - mae: 9.4130
# Epoch 497/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.1554 - mae: 9.4087
# Epoch 498/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.2612 - mae: 9.4057
# Epoch 499/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.4043 - mae: 9.4303
# Epoch 500/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.5792 - mae: 9.4333
# Epoch 501/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 166.2680 - mae: 9.4014
# Epoch 502/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 165.0544 - mae: 9.3730
# Epoch 503/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 165.5374 - mae: 9.3948
# Epoch 504/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 167.0070 - mae: 9.4185
# Epoch 505/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 165.4406 - mae: 9.3889
# Epoch 506/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.4558 - mae: 9.3536
# Epoch 507/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 165.2436 - mae: 9.4038
# Epoch 508/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 165.2473 - mae: 9.3718
# Epoch 509/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.9400 - mae: 9.3886
# Epoch 510/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 164.4366 - mae: 9.3695
# Epoch 511/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 165.1983 - mae: 9.3791
# Epoch 512/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 164.0854 - mae: 9.3553
# Epoch 513/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 164.6142 - mae: 9.3618
# Epoch 514/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 165.3411 - mae: 9.3882
# Epoch 515/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 165.1374 - mae: 9.3820
# Epoch 516/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 163.6737 - mae: 9.3549
# Epoch 517/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 163.6620 - mae: 9.3351
# Epoch 518/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.4833 - mae: 9.3554
# Epoch 519/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.3288 - mae: 9.3609
# Epoch 520/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 163.3141 - mae: 9.3262
# Epoch 521/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.5973 - mae: 9.3795
# Epoch 522/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.0812 - mae: 9.3555
# Epoch 523/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.8002 - mae: 9.3715
# Epoch 524/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 163.0969 - mae: 9.3237
# Epoch 525/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 162.7085 - mae: 9.3197
# Epoch 526/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.0452 - mae: 9.3510
# Epoch 527/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 163.3018 - mae: 9.3338
# Epoch 528/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 162.2598 - mae: 9.3021
# Epoch 529/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 163.2750 - mae: 9.3233
# Epoch 530/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 164.1911 - mae: 9.3493
# Epoch 531/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 162.0890 - mae: 9.2896
# Epoch 532/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.8987 - mae: 9.3655
# Epoch 533/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 162.5353 - mae: 9.3042
# Epoch 534/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 162.0755 - mae: 9.2977
# Epoch 535/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 163.7372 - mae: 9.3433
# Epoch 536/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 162.7105 - mae: 9.3103
# Epoch 537/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 163.5490 - mae: 9.3314
# Epoch 538/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 163.2677 - mae: 9.3447
# Epoch 539/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 162.0821 - mae: 9.2930
# Epoch 540/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 161.9986 - mae: 9.2994
# Epoch 541/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 164.9520 - mae: 9.3785
# Epoch 542/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 162.3241 - mae: 9.2963
# Epoch 543/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 162.1544 - mae: 9.2961
# Epoch 544/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 161.2086 - mae: 9.2661
# Epoch 545/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 161.9894 - mae: 9.2742
# Epoch 546/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 162.3419 - mae: 9.3098
# Epoch 547/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.9411 - mae: 9.2476
# Epoch 548/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 161.6212 - mae: 9.2710
# Epoch 549/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 162.8841 - mae: 9.3210
# Epoch 550/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 161.5351 - mae: 9.2861
# Epoch 551/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 159.1448 - mae: 9.2155
# Epoch 552/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 161.2971 - mae: 9.2750
# Epoch 553/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 161.4401 - mae: 9.2865
# Epoch 554/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.9176 - mae: 9.2633
# Epoch 555/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 161.0482 - mae: 9.2662
# Epoch 556/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.4743 - mae: 9.2555
# Epoch 557/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 161.6765 - mae: 9.2847
# Epoch 558/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.9138 - mae: 9.2622
# Epoch 559/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.0792 - mae: 9.2540
# Epoch 560/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.1194 - mae: 9.2397
# Epoch 561/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.2263 - mae: 9.2448
# Epoch 562/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.3707 - mae: 9.2449
# Epoch 563/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 161.0076 - mae: 9.2569
# Epoch 564/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.0748 - mae: 9.2327
# Epoch 565/1000
# 72/72 [==============================] - 1s 17ms/step - loss: 160.5934 - mae: 9.2611
# Epoch 566/1000
# 72/72 [==============================] - 1s 18ms/step - loss: 160.3768 - mae: 9.2406

# %%
pred = model.predict(testX)

pred = pred.reshape(-1,1)
true = testY.reshape(-1,1)

## pred = sc.inverse_transform(pred)
# Out:
# 987/987 [==============================] - 2s 2ms/step

# %%
## Visualising the results
plt.plot(true, color='red')
plt.plot(pred, color='blue')
plt.show()

# %%
## 개선 후 재실행 예정
# best_model = tf.keras.models.load_model("../models/V2.h5", custom_objects={"TCN": TCN}, compile=False)
# y_preds = best_model.predict(ds_test)

# df_answer = pd.read_csv("../data/sample_submission.csv")
# df_answer.loc[:, ["wl_1018662" ,"wl_1018680", "wl_1018683", "wl_1019630"]] = y_preds
# df_answer.to_csv("../results/V2.csv", index=False)

# %%
model_preds = pred
d_actual = true

from sklearn.metrics import mean_absolute_percentage_error
print('mean_absolute_percentage_error : ', mean_absolute_percentage_error(d_actual, model_preds))

from sklearn.metrics import mean_absolute_error
print('mean_absolute_error : ', mean_absolute_error(d_actual, model_preds))                                      

from sklearn.metrics import mean_squared_error
print('mean_squared_error : ', mean_squared_error(d_actual, model_preds))

from sklearn.metrics import r2_score   # model.score
print('r2_score : ', r2_score(d_actual, model_preds))
# Out:
# mean_absolute_percentage_error :  0.35818238712092043
# mean_absolute_error :  25.24051821964717
# mean_squared_error :  1364.4199053917257
# r2_score :  0.480757723037746
